# %%
import pandas as pd

# %%
df = pd.read_csv("Student_Performance.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.tail()
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
#       Sample Question Papers Practiced  Performance Index
# 9995                                 2               23.0
# 9996                                 5               58.0
# 9997                                 5               74.0
# 9998                                 0               95.0
# 9999                                 1               64.0

# %%
df.describe()
# Out:
#        Hours Studied  Previous Scores   Sleep Hours  \
# count   10000.000000     10000.000000  10000.000000
# mean        4.992900        69.445700      6.530600
# std         2.589309        17.343152      1.695863
# min         1.000000        40.000000      4.000000
# 25%         3.000000        54.000000      5.000000
# 50%         5.000000        69.000000      7.000000
# 75%         7.000000        85.000000      8.000000
# max         9.000000        99.000000      9.000000
#
#        Sample Question Papers Practiced  Performance Index
# count                      10000.000000       10000.000000
# mean                           4.583300          55.224800
# std                            2.867348          19.212558
# min                            0.000000          10.000000
# 25%                            2.000000          40.000000
# 50%                            5.000000          55.000000
# 75%                            7.000000          71.000000
# ...

# %%
df.isnull().sum()
#if null value i wil go for imputation
# Out:
# Hours Studied                       0
# Previous Scores                     0
# Extracurricular Activities          0
# Sleep Hours                         0
# Sample Question Papers Practiced    0
# Performance Index                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Hours Studied                         int64
# Previous Scores                       int64
# Extracurricular Activities           object
# Sleep Hours                           int64
# Sample Question Papers Practiced      int64
# Performance Index                   float64
# dtype: object

# %%
#import scikit preprocessing from scikit.learn
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
le = LabelEncoder()
le.fit_transform(df["Extracurricular Activities"])
#encoding technique
# Out:
# array([1, 0, 1, ..., 1, 1, 0], shape=(10000,))

# %%
df["Extracurricular Activities"] = le.fit_transform(df["Extracurricular Activities"])

# %%
df
# Out:
#       Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0                 7               99                           1            9
# 1                 4               82                           0            4
# 2                 8               51                           1            7
# 3                 5               52                           1            5
# 4                 7               75                           0            8
# ...             ...              ...                         ...          ...
# 9995              1               49                           1            4
# 9996              7               64                           1            8
# 9997              6               83                           1            8
# 9998              9               97                           1            7
# 9999              7               74                           0            8
#
# ...

# %%
x = df[["Hours Studied",	"Previous Scores",	"Extracurricular Activities",	"Sleep Hours",	"Sample Question Papers Practiced"]]

# %%
x.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0              7               99                           1            9
# 1              4               82                           0            4
# 2              8               51                           1            7
# 3              5               52                           1            5
# 4              7               75                           0            8
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# 2                                 2
# 3                                 2
# 4                                 5

# %%
y=  df["Performance Index"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2, train_size=0.8)

# %%
X

# %%
#before training we have to do preprocessing

# %%
#Z = (x-u/sigma) sigma= std, u = average, x= data

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
import pickle
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
#evaluation metrics

# %%
model = LinearRegression()
model.fit(x_train_scaled, y_train)
# Out:
# LinearRegression()

# %%
y_predict = model.predict(x_test_scaled)

# %%
mean_squared_error(y_test, y_predict)
#y-y_cap
# Out:
# 4.307385284531408

# %%
r2_score(y_test, y_predict)
# Out:
# 0.9884948450260223

# %%
import pickle
with open("student_lr_final_model.pkl", 'wb') as file:
    pickle.dump((model, scaler, le), file)

# %%
#!pip install streamlit
# Out:
# ...
#    ---------------------------------------- 0.0/10.1 MB ? eta -:--:--
#    ----- ---------------------------------- 1.3/10.1 MB 6.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 2.9/10.1 MB 6.8 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.2/10.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 5.8/10.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/10.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.7/10.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------  10.0/10.1 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 10.1/10.1 MB 6.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/731.2 kB ? eta -:--:--
#    ---------------------------------------- 731.2/731.2 kB 6.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
# ...
